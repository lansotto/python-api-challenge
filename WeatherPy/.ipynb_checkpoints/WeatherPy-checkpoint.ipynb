# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
cities
# Out:
# Number of cities in the list: 611
# ['vila franca do campo',
#  'male',
#  'at-bashi',
#  'ushuaia',
#  'jamestown',
#  'college',
#  'los llanos de aridane',
#  'hasaki',
#  'saleaula',
#  'severo-kurilsk',
#  'vaini',
#  'mataura',
#  'busselton',
#  'albany',
#  'castel volturno',
#  'rikitea',
#  'illoqqortoormiut',
#  'puerto ayora',
#  'hilo',
#  'nazas',
#  'hami',
#  'cherskiy',
#  'laguna',
#  'bambous virieux',
#  'butaritari',
#  'shingu',
#  'atuona',
#  'maceio',
#  'cape town',
#  'amderma',
#  'bardiyah',
#  'clyde river',
#  'sao filipe',
#  'meyungs',
#  'kapaa',
#  'avarua',
#  'punta arenas',
#  'lebu',
#  'mongo',
#  'airai',
#  'qaanaaq',
#  'dunedin',
#  'grand river south east',
#  'hobart',
#  'torbay',
#  'hithadhoo',
#  'chachapoyas',
#  'pisco',
#  'shimoda',
#  'hermanus',
#  'port alfred',
#  'luganville',
#  'damaturu',
#  'sampit',
#  'benghazi',
#  'chokurdakh',
#  'chute-aux-outardes',
#  'thompson',
#  'bengkulu',
#  'papillion',
#  'flinders',
#  'georgetown',
#  'padang',
#  'comodoro rivadavia',
#  'tymovskoye',
#  'thomasville',
#  'harper',
#  'strelka',
#  'srednekolymsk',
#  'cap malheureux',
#  'tasiilaq',
#  'keningau',
#  'barentsburg',
#  'bluff',
#  'narsaq',
#  'rapid city',
#  'svetlyy',
#  'naze',
#  'hobyo',
#  'port hardy',
#  'ibra',
#  'labuhan',
#  'xai-xai',
#  'geraldton',
#  'qasigiannguit',
#  'saint-francois',
#  'troitskoye',
#  'ulundi',
#  'dikson',
#  'bobo dioulasso',
#  'mahebourg',
#  'east london',
#  'rudnaya pristan',
#  'yelizovo',
#  'salinas',
#  'longyearbyen',
#  'kulhudhuffushi',
#  'masunga',
#  'carlisle',
#  'betsiamites',
#  'saint-philippe',
#  'alofi',
#  'port shepstone',
#  'san quintin',
#  'arraial do cabo',
#  'caravelas',
#  'lagoa',
#  'upernavik',
#  'tolaga bay',
#  'jacareacanga',
#  'dingle',
#  'panaba',
#  'taolanaro',
#  'oktyabrskoye',
#  'bredasdorp',
#  'inhambane',
#  'codrington',
#  'new norfolk',
#  'fort pierce',
#  'saskylakh',
#  'dormidontovka',
#  'dayong',
#  'aubenas',
#  'santa cruz de tenerife',
#  'hofn',
#  'emirdag',
#  'atbasar',
#  'mount gambier',
#  'goderich',
#  'kangaatsiaq',
#  'carnarvon',
#  'pevek',
#  'williams lake',
#  'esperance',
#  'echirolles',
#  'majene',
#  'letychiv',
#  'zhezkazgan',
#  'souillac',
#  'vestmanna',
#  'lac du bonnet',
#  'undory',
#  'reconquista',
#  'berbera',
#  'talnakh',
#  'khatanga',
#  'mendahara',
#  'namanyere',
#  'menongue',
#  'mouzouras',
#  'muros',
#  'barrow',
#  'ingham',
#  'santa marta',
#  'sussex',
#  'provideniya',
#  'kalabo',
#  'ocosingo',
#  'kanigoro',
#  'hambantota',
#  'yellowknife',
#  'general pico',
#  'umtata',
#  'batemans bay',
#  'esil',
#  'constitucion',
#  'samarai',
#  'palmaner',
#  'sosua',
#  'kilindoni',
#  'acapulco',
#  'ouahigouya',
#  'ribeira grande',
#  'mar del plata',
#  'san cristobal',
#  'castro',
#  'aklavik',
#  'hay river',
#  'broome',
#  'aripuana',
#  'ikeda',
#  'zhangye',
#  'krasnoselkup',
#  'burgess hill',
#  'doha',
#  'cabo san lucas',
#  'bethel',
#  'chipiona',
#  'sentyabrskiy',
#  'cockburn town',
#  'tommot',
#  'houma',
#  'visnes',
#  'herat',
#  'rancho veloz',
#  'nuuk',
#  'nanortalik',
#  'nome',
#  'kabanjahe',
#  'felanitx',
#  'rungata',
#  'huaiyuan',
#  'pakxan',
#  'kavieng',
#  'awjilah',
#  'coihaique',
#  'buba',
#  'ilulissat',
#  'uthal',
#  'jalu',
#  'tuktoyaktuk',
#  'kabinda',
#  'victoria',
#  'kruisfontein',
#  'vestmannaeyjar',
#  'nouadhibou',
#  'ponta do sol',
#  'kodiak',
#  'athabasca',
#  'wulanhaote',
#  'aranos',
#  'narovchat',
#  'kimbe',
#  'eyl',
#  'grindavik',
#  'buon me thuot',
#  'sitka',
#  'pokhara',
#  'mariestad',
#  'avera',
#  'kiama',
#  'san patricio',
#  'cidreira',
#  'kaitangata',
#  'brattvag',
#  'cao bang',
#  'saint george',
#  'ahipara',
#  'nizhneyansk',
#  'salalah',
#  'melfi',
#  'camacupa',
#  'mengcheng',
#  'touros',
#  'guerrero negro',
#  'peruibe',
#  'snasa',
#  'praia da vitoria',
#  'stephenville',
#  'attawapiskat',
#  'fairbanks',
#  'nago',
#  'san vicente',
#  'ngukurr',
#  'korla',
#  'sao felix do xingu',
#  'merauke',
#  'armidale',
#  'saint-georges',
#  'batagay-alyta',
#  'quatre cocos',
#  'nikolskoye',
#  'belushya guba',
#  'la ronge',
#  'tavares',
#  'dwarka',
#  'kurilsk',
#  'rosarno',
#  'jabiru',
#  'mrirt',
#  'vila do maio',
#  'mosjoen',
#  'brae',
#  'kirgiz-miyaki',
#  'shubarkuduk',
#  'northam',
#  'mayumba',
#  'strezhevoy',
#  'garowe',
#  'kozhva',
#  'egvekinot',
#  'wufeng',
#  'nieuw amsterdam',
#  'jackson',
#  'jinan',
#  'buchanan',
#  'sinjah',
#  'guaratinga',
#  'xinye',
#  'tidore',
#  'tautira',
#  'moron',
#  'sao jose da coroa grande',
#  'yantal',
#  'sesimbra',
#  'iqaluit',
#  'viligili',
#  'camapua',
#  'jumla',
#  'filingue',
#  'jojoima',
#  'kaeo',
#  'andros town',
#  'perth',
#  'wanning',
#  'puerto del rosario',
#  'fredericksburg',
#  'kingaroy',
#  'aztec',
#  'manzhouli',
#  'carutapera',
#  'faanui',
#  'toliary',
#  'codajas',
#  'labutta',
#  'nakambala',
#  'coolum beach',
#  'palabuhanratu',
#  'sao joao da barra',
#  'port elizabeth',
#  'taltal',
#  'morgan city',
#  'nador',
#  'tiksi',
#  'hualmay',
#  'liverpool',
#  'coari',
#  'pocone',
#  'richards bay',
#  'port lincoln',
#  'terra rica',
#  'atar',
#  'khvastovichi',
#  'barawe',
#  'arman',
#  'yulara',
#  'terney',
#  'vargashi',
#  'hof',
#  'klaksvik',
#  'ibotirama',
#  'niquelandia',
#  'kirakira',
#  'vanino',
#  'batagay',
#  'tarn taran',
#  'orlik',
#  'otjimbingwe',
#  'belmonte',
#  'pemangkat',
#  'ancud',
#  'samusu',
#  'mount isa',
#  'heihe',
#  'walvis bay',
#  'qujing',
#  'tessaoua',
#  'lawrenceburg',
#  'whitefish',
#  'olinda',
#  'dubuque',
#  'bulgan',
#  'mabaruma',
#  'ulaangom',
#  'gadung',
#  'chutove',
#  'guanica',
#  'tuatapere',
#  'biltine',
#  'deputatskiy',
#  'ballina',
#  'sola',
#  'petropavlovsk-kamchatskiy',
#  'aykhal',
#  'emba',
#  'campina verde',
#  'mezhdurechensk',
#  'eureka',
#  'luanda',
#  'saint augustine',
#  'hearst',
#  'norman wells',
#  'peace river',
#  'khani',
#  'marfino',
#  'honningsvag',
#  'isangel',
#  'namatanai',
#  'yagodnoye',
#  'valdivia',
#  'pangoa',
#  'mahina',
#  'bambanglipuro',
#  'kamenskoye',
#  'campo verde',
#  'jabinyanah',
#  'puerto leguizamo',
#  'sanandaj',
#  'augustow',
#  'bom jesus',
#  'taoudenni',
#  'nyurba',
#  'payson',
#  'urucara',
#  'moa',
#  'sena madureira',
#  'beawar',
#  'lumeje',
#  'saint-dizier',
#  'shahrud',
#  'sechura',
#  'nelson bay',
#  'porto novo',
#  'palana',
#  'san rafael',
#  'tsihombe',
#  'utiroa',
#  'maneadero',
#  'makokou',
#  'fairview',
#  'isoka',
#  'tambacounda',
#  'bondo',
#  'katsuura',
#  'saint pete beach',
#  'nagato',
#  'camacha',
#  'malinovoye ozero',
#  'silver city',
#  'nalagarh',
#  'auki',
#  'buraydah',
#  'limbang',
#  'olafsvik',
#  'riyaq',
#  'maldonado',
#  'mutsamudu',
#  'oktyabrskiy',
#  'bonavista',
#  'shitanjing',
#  'glendive',
#  'gat',
#  'dobson',
#  'barra do garcas',
#  'tarko-sale',
#  'aksarka',
#  'turtkul',
#  'murgab',
#  'puerto ayacucho',
#  'maua',
#  'sur',
#  'vila velha',
#  'tabou',
#  'fare',
#  'chuy',
#  'yelnya',
#  'port hedland',
#  'mahon',
#  'rantepao',
#  'nong khae',
#  'rocha',
#  'ondjiva',
#  'auning',
#  'port-de-bouc',
#  'moerai',
#  'pteleos',
#  'altoona',
#  'san jeronimo',
#  'tumannyy',
#  'krasnyy chikoy',
#  'westport',
#  'rize',
#  'vaitupu',
#  'namibe',
#  'henties bay',
#  'erenhot',
#  'xichang',
#  'karasjok',
#  'cervo',
#  'isiro',
#  'yeppoon',
#  'yerbogachen',
#  'shatsk',
#  'emmett',
#  'aasiaat',
#  'kamaishi',
#  'nanakuli',
#  'omboue',
#  'kuche',
#  'panguma',
#  'tandil',
#  'darhan',
#  'los angeles',
#  'flin flon',
#  'wajima',
#  'santa maria',
#  'yeletskiy',
#  'lasa',
#  'bonthe',
#  'jiuquan',
#  'djambala',
#  'praia',
#  'dalbandin',
#  'koslan',
#  'boysun',
#  'mezen',
#  'kinango',
#  'khasan',
#  'berlevag',
#  'banjar',
#  'skibbereen',
#  'rehoboth',
#  'harbour breton',
#  'elk city',
#  'khonuu',
#  'kosh-agach',
#  'margate',
#  'kodinsk',
#  'natal',
#  'benguela',
#  'dejen',
#  'los barrios',
#  'ardabil',
#  'lavrentiya',
#  'kirovskiy',
#  'clarence town',
#  'mutis',
#  'marevo',
#  'uruzgan',
#  'la rioja',
#  'halifax',
#  'agboville',
#  'umm kaddadah',
#  'curup',
#  'lompoc',
#  'knyaze-volkonskoye',
#  'nizhnedevitsk',
#  'turukhansk',
#  'labuan',
#  'tigil',
#  'uyuni',
#  'qandala',
#  'sisimiut',
#  'mys shmidta',
#  'hashtrud',
#  'carmo do rio claro',
#  'kinston',
#  'khudumelapye',
#  'zachagansk',
#  'nishihara',
#  'pitimbu',
#  'bredy',
#  'fort dodge',
#  'abu samrah',
#  'cumra',
#  'bud',
#  'conde',
#  'antalaha',
#  'tankhoy',
#  'anadyr',
#  'livermore',
#  'martapura',
#  'the valley',
#  'saldanha',
#  'goundam',
#  'yola',
#  'palmer',
#  'soyo',
#  'hun',
#  'nantucket',
#  'bolungarvik',
#  'kindu',
#  'bandarbeyla',
#  'nanga eboko',
#  'gazanjyk',
#  'tabuk',
#  'grand gaube',
#  'lata',
#  'calasuche',
#  'muzhi',
#  'kalbay',
#  'ixtapa',
#  'conceicao do mato dentro',
#  'ende',
#  'huron',
#  'rameshki',
#  'cururupu',
#  'coachella',
#  'okha',
#  'luena',
#  'bima',
#  'hovd',
#  'tubruq',
#  'mayo',
#  'parana',
#  'kachikau',
#  'toba',
#  'rorvik',
#  'valparaiso',
#  'san francisco',
#  'half moon bay',
#  'dali',
#  'nizhneudinsk',
#  'cagayan de tawi-tawi',
#  'tawkar',
#  'bekhteyevka',
#  'yazman',
#  'zhangjiakou',
#  'noumea',
#  'that phanom',
#  'trenggalek']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q=" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city.title() + "&appid=" + weather_api_key
       
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(url + city_url).json()
        #json.dumps(response_json, indent=4, sort_keys=True)
        #city_weather = response_json["weather"]
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]
        city_wind = response_json["wind"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila franca do campo
# Processing Record 2 of Set 1 | male
# Processing Record 3 of Set 1 | at-bashi
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | los llanos de aridane
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | castel volturno
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | nazas
# Processing Record 21 of Set 1 | hami
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | shingu
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | maceio
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | bardiyah
# Processing Record 32 of Set 1 | clyde river
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | mongo
# Processing Record 40 of Set 1 | airai
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | dunedin
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | chachapoyas
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | shimoda
# Processing Record 50 of Set 1 | hermanus
# Processing Record 0 of Set 2 | port alfred
# Processing Record 1 of Set 2 | luganville
# Processing Record 2 of Set 2 | damaturu
# Processing Record 3 of Set 2 | sampit
# Processing Record 4 of Set 2 | benghazi
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | chute-aux-outardes
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | papillion
# Processing Record 10 of Set 2 | flinders
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | padang
# Processing Record 13 of Set 2 | comodoro rivadavia
# Processing Record 14 of Set 2 | tymovskoye
# Processing Record 15 of Set 2 | thomasville
# Processing Record 16 of Set 2 | harper
# Processing Record 17 of Set 2 | strelka
# Processing Record 18 of Set 2 | srednekolymsk
# Processing Record 19 of Set 2 | cap malheureux
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | keningau
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | narsaq
# Processing Record 25 of Set 2 | rapid city
# Processing Record 26 of Set 2 | svetlyy
# Processing Record 27 of Set 2 | naze
# Processing Record 28 of Set 2 | hobyo
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | ibra
# Processing Record 31 of Set 2 | labuhan
# Processing Record 32 of Set 2 | xai-xai
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | qasigiannguit
# Processing Record 35 of Set 2 | saint-francois
# Processing Record 36 of Set 2 | troitskoye
# Processing Record 37 of Set 2 | ulundi
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | bobo dioulasso
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | rudnaya pristan
# Processing Record 43 of Set 2 | yelizovo
# Processing Record 44 of Set 2 | salinas
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | kulhudhuffushi
# Processing Record 47 of Set 2 | masunga
# Processing Record 48 of Set 2 | carlisle
# Processing Record 49 of Set 2 | betsiamites
# Processing Record 0 of Set 3 | saint-philippe
# Processing Record 1 of Set 3 | alofi
# Processing Record 2 of Set 3 | port shepstone
# Processing Record 3 of Set 3 | san quintin
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | lagoa
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | tolaga bay
# Processing Record 9 of Set 3 | jacareacanga
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | panaba
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | oktyabrskoye
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | inhambane
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | fort pierce
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | dormidontovka
# Processing Record 21 of Set 3 | dayong
# Processing Record 22 of Set 3 | aubenas
# Processing Record 23 of Set 3 | santa cruz de tenerife
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | emirdag
# Processing Record 26 of Set 3 | atbasar
# Processing Record 27 of Set 3 | mount gambier
# Processing Record 28 of Set 3 | goderich
# Processing Record 29 of Set 3 | kangaatsiaq
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | williams lake
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | echirolles
# Processing Record 35 of Set 3 | majene
# Processing Record 36 of Set 3 | letychiv
# Processing Record 37 of Set 3 | zhezkazgan
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | vestmanna
# Processing Record 40 of Set 3 | lac du bonnet
# Processing Record 41 of Set 3 | undory
# Processing Record 42 of Set 3 | reconquista
# Processing Record 43 of Set 3 | berbera
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 47 of Set 3 | namanyere
# Processing Record 48 of Set 3 | menongue
# Processing Record 49 of Set 3 | mouzouras
# Processing Record 0 of Set 4 | muros
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | ingham
# Processing Record 3 of Set 4 | santa marta
# Processing Record 4 of Set 4 | sussex
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | kalabo
# Processing Record 7 of Set 4 | ocosingo
# Processing Record 8 of Set 4 | kanigoro
# Processing Record 9 of Set 4 | hambantota
# Processing Record 10 of Set 4 | yellowknife
# Processing Record 11 of Set 4 | general pico
# Processing Record 12 of Set 4 | umtata
# Processing Record 13 of Set 4 | batemans bay
# Processing Record 14 of Set 4 | esil
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | samarai
# Processing Record 17 of Set 4 | palmaner
# Processing Record 18 of Set 4 | sosua
# Processing Record 19 of Set 4 | kilindoni
# Processing Record 20 of Set 4 | acapulco
# Processing Record 21 of Set 4 | ouahigouya
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | aklavik
# Processing Record 27 of Set 4 | hay river
# Processing Record 28 of Set 4 | broome
# Processing Record 29 of Set 4 | aripuana
# Processing Record 30 of Set 4 | ikeda
# Processing Record 31 of Set 4 | zhangye
# Processing Record 32 of Set 4 | krasnoselkup
# Processing Record 33 of Set 4 | burgess hill
# Processing Record 34 of Set 4 | doha
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | chipiona
# Processing Record 38 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | tommot
# Processing Record 41 of Set 4 | houma
# Processing Record 42 of Set 4 | visnes
# Processing Record 43 of Set 4 | herat
# Processing Record 44 of Set 4 | rancho veloz
# Processing Record 45 of Set 4 | nuuk
# Processing Record 46 of Set 4 | nanortalik
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | kabanjahe
# Processing Record 49 of Set 4 | felanitx
# Processing Record 0 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | huaiyuan
# Processing Record 2 of Set 5 | pakxan
# Processing Record 3 of Set 5 | kavieng
# Processing Record 4 of Set 5 | awjilah
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | buba
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | uthal
# Processing Record 9 of Set 5 | jalu
# Processing Record 10 of Set 5 | tuktoyaktuk
# Processing Record 11 of Set 5 | kabinda
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | nouadhibou
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | athabasca
# Processing Record 19 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 5 | aranos
# Processing Record 21 of Set 5 | narovchat
# Processing Record 22 of Set 5 | kimbe
# Processing Record 23 of Set 5 | eyl
# Processing Record 24 of Set 5 | grindavik
# Processing Record 25 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 26 of Set 5 | sitka
# Processing Record 27 of Set 5 | pokhara
# Processing Record 28 of Set 5 | mariestad
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | kiama
# Processing Record 31 of Set 5 | san patricio
# Processing Record 32 of Set 5 | cidreira
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | brattvag
# Processing Record 35 of Set 5 | cao bang
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | ahipara
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | melfi
# Processing Record 41 of Set 5 | camacupa
# Processing Record 42 of Set 5 | mengcheng
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | peruibe
# Processing Record 46 of Set 5 | snasa
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | stephenville
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 6 | fairbanks
# Processing Record 1 of Set 6 | nago
# Processing Record 2 of Set 6 | san vicente
# Processing Record 3 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 6 | korla
# Processing Record 5 of Set 6 | sao felix do xingu
# Processing Record 6 of Set 6 | merauke
# Processing Record 7 of Set 6 | armidale
# Processing Record 8 of Set 6 | saint-georges
# Processing Record 9 of Set 6 | batagay-alyta
# Processing Record 10 of Set 6 | quatre cocos
# Processing Record 11 of Set 6 | nikolskoye
# Processing Record 12 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 6 | la ronge
# Processing Record 14 of Set 6 | tavares
# Processing Record 15 of Set 6 | dwarka
# Processing Record 16 of Set 6 | kurilsk
# Processing Record 17 of Set 6 | rosarno
# Processing Record 18 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 6 | vila do maio
# Processing Record 21 of Set 6 | mosjoen
# Processing Record 22 of Set 6 | brae
# Processing Record 23 of Set 6 | kirgiz-miyaki
# Processing Record 24 of Set 6 | shubarkuduk
# Processing Record 25 of Set 6 | northam
# Processing Record 26 of Set 6 | mayumba
# Processing Record 27 of Set 6 | strezhevoy
# Processing Record 28 of Set 6 | garowe
# Processing Record 29 of Set 6 | kozhva
# Processing Record 30 of Set 6 | egvekinot
# Processing Record 31 of Set 6 | wufeng
# Processing Record 32 of Set 6 | nieuw amsterdam
# Processing Record 33 of Set 6 | jackson
# Processing Record 34 of Set 6 | jinan
# Processing Record 35 of Set 6 | buchanan
# Processing Record 36 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 37 of Set 6 | guaratinga
# Processing Record 38 of Set 6 | xinye
# Processing Record 39 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 6 | tautira
# Processing Record 41 of Set 6 | moron
# Processing Record 42 of Set 6 | sao jose da coroa grande
# Processing Record 43 of Set 6 | yantal
# Processing Record 44 of Set 6 | sesimbra
# Processing Record 45 of Set 6 | iqaluit
# Processing Record 46 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 6 | camapua
# Processing Record 48 of Set 6 | jumla
# Processing Record 49 of Set 6 | filingue
# Processing Record 0 of Set 7 | jojoima
# Processing Record 1 of Set 7 | kaeo
# Processing Record 2 of Set 7 | andros town
# Processing Record 3 of Set 7 | perth
# Processing Record 4 of Set 7 | wanning
# Processing Record 5 of Set 7 | puerto del rosario
# Processing Record 6 of Set 7 | fredericksburg
# Processing Record 7 of Set 7 | kingaroy
# Processing Record 8 of Set 7 | aztec
# Processing Record 9 of Set 7 | manzhouli
# Processing Record 10 of Set 7 | carutapera
# Processing Record 11 of Set 7 | faanui
# Processing Record 12 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 7 | codajas
# Processing Record 14 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 7 | nakambala
# Processing Record 16 of Set 7 | coolum beach
# Processing Record 17 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 7 | sao joao da barra
# Processing Record 19 of Set 7 | port elizabeth
# Processing Record 20 of Set 7 | taltal
# Processing Record 21 of Set 7 | morgan city
# Processing Record 22 of Set 7 | nador
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | liverpool
# Processing Record 26 of Set 7 | coari
# Processing Record 27 of Set 7 | pocone
# Processing Record 28 of Set 7 | richards bay
# Processing Record 29 of Set 7 | port lincoln
# Processing Record 30 of Set 7 | terra rica
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | khvastovichi
# Processing Record 33 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 7 | arman
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | terney
# Processing Record 37 of Set 7 | vargashi
# Processing Record 38 of Set 7 | hof
# Processing Record 39 of Set 7 | klaksvik
# Processing Record 40 of Set 7 | ibotirama
# Processing Record 41 of Set 7 | niquelandia
# Processing Record 42 of Set 7 | kirakira
# Processing Record 43 of Set 7 | vanino
# Processing Record 44 of Set 7 | batagay
# Processing Record 45 of Set 7 | tarn taran
# Processing Record 46 of Set 7 | orlik
# Processing Record 47 of Set 7 | otjimbingwe
# Processing Record 48 of Set 7 | belmonte
# Processing Record 49 of Set 7 | pemangkat
# Processing Record 0 of Set 8 | ancud
# Processing Record 1 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 8 | mount isa
# Processing Record 3 of Set 8 | heihe
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | qujing
# Processing Record 6 of Set 8 | tessaoua
# Processing Record 7 of Set 8 | lawrenceburg
# Processing Record 8 of Set 8 | whitefish
# Processing Record 9 of Set 8 | olinda
# Processing Record 10 of Set 8 | dubuque
# Processing Record 11 of Set 8 | bulgan
# Processing Record 12 of Set 8 | mabaruma
# Processing Record 13 of Set 8 | ulaangom
# Processing Record 14 of Set 8 | gadung
# Processing Record 15 of Set 8 | chutove
# Processing Record 16 of Set 8 | guanica
# Processing Record 17 of Set 8 | tuatapere
# Processing Record 18 of Set 8 | biltine
# Processing Record 19 of Set 8 | deputatskiy
# Processing Record 20 of Set 8 | ballina
# Processing Record 21 of Set 8 | sola
# Processing Record 22 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 8 | aykhal
# Processing Record 24 of Set 8 | emba
# Processing Record 25 of Set 8 | campina verde
# Processing Record 26 of Set 8 | mezhdurechensk
# Processing Record 27 of Set 8 | eureka
# Processing Record 28 of Set 8 | luanda
# Processing Record 29 of Set 8 | saint augustine
# Processing Record 30 of Set 8 | hearst
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | peace river
# Processing Record 33 of Set 8 | khani
# Processing Record 34 of Set 8 | marfino
# Processing Record 35 of Set 8 | honningsvag
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | namatanai
# Processing Record 38 of Set 8 | yagodnoye
# Processing Record 39 of Set 8 | valdivia
# Processing Record 40 of Set 8 | pangoa
# Processing Record 41 of Set 8 | mahina
# Processing Record 42 of Set 8 | bambanglipuro
# Processing Record 43 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 8 | campo verde
# Processing Record 45 of Set 8 | jabinyanah
# Processing Record 46 of Set 8 | puerto leguizamo
# Processing Record 47 of Set 8 | sanandaj
# Processing Record 48 of Set 8 | augustow
# Processing Record 49 of Set 8 | bom jesus
# Processing Record 0 of Set 9 | taoudenni
# Processing Record 1 of Set 9 | nyurba
# Processing Record 2 of Set 9 | payson
# Processing Record 3 of Set 9 | urucara
# Processing Record 4 of Set 9 | moa
# Processing Record 5 of Set 9 | sena madureira
# Processing Record 6 of Set 9 | beawar
# Processing Record 7 of Set 9 | lumeje
# Processing Record 8 of Set 9 | saint-dizier
# Processing Record 9 of Set 9 | shahrud
# Processing Record 10 of Set 9 | sechura
# Processing Record 11 of Set 9 | nelson bay
# Processing Record 12 of Set 9 | porto novo
# Processing Record 13 of Set 9 | palana
# Processing Record 14 of Set 9 | san rafael
# Processing Record 15 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 9 | maneadero
# Processing Record 18 of Set 9 | makokou
# Processing Record 19 of Set 9 | fairview
# Processing Record 20 of Set 9 | isoka
# Processing Record 21 of Set 9 | tambacounda
# Processing Record 22 of Set 9 | bondo
# Processing Record 23 of Set 9 | katsuura
# Processing Record 24 of Set 9 | saint pete beach
# Processing Record 25 of Set 9 | nagato
# Processing Record 26 of Set 9 | camacha
# Processing Record 27 of Set 9 | malinovoye ozero
# Processing Record 28 of Set 9 | silver city
# Processing Record 29 of Set 9 | nalagarh
# Processing Record 30 of Set 9 | auki
# Processing Record 31 of Set 9 | buraydah
# Processing Record 32 of Set 9 | limbang
# Processing Record 33 of Set 9 | olafsvik
# Processing Record 34 of Set 9 | riyaq
# City not found. Skipping...
# Processing Record 35 of Set 9 | maldonado
# Processing Record 36 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 9 | oktyabrskiy
# Processing Record 38 of Set 9 | bonavista
# Processing Record 39 of Set 9 | shitanjing
# Processing Record 40 of Set 9 | glendive
# Processing Record 41 of Set 9 | gat
# Processing Record 42 of Set 9 | dobson
# Processing Record 43 of Set 9 | barra do garcas
# Processing Record 44 of Set 9 | tarko-sale
# Processing Record 45 of Set 9 | aksarka
# Processing Record 46 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 47 of Set 9 | murgab
# Processing Record 48 of Set 9 | puerto ayacucho
# Processing Record 49 of Set 9 | maua
# Processing Record 0 of Set 10 | sur
# Processing Record 1 of Set 10 | vila velha
# Processing Record 2 of Set 10 | tabou
# Processing Record 3 of Set 10 | fare
# Processing Record 4 of Set 10 | chuy
# Processing Record 5 of Set 10 | yelnya
# Processing Record 6 of Set 10 | port hedland
# Processing Record 7 of Set 10 | mahon
# Processing Record 8 of Set 10 | rantepao
# Processing Record 9 of Set 10 | nong khae
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | ondjiva
# Processing Record 12 of Set 10 | auning
# Processing Record 13 of Set 10 | port-de-bouc
# Processing Record 14 of Set 10 | moerai
# Processing Record 15 of Set 10 | pteleos
# Processing Record 16 of Set 10 | altoona
# Processing Record 17 of Set 10 | san jeronimo
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | krasnyy chikoy
# Processing Record 20 of Set 10 | westport
# Processing Record 21 of Set 10 | rize
# Processing Record 22 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 10 | namibe
# Processing Record 24 of Set 10 | henties bay
# Processing Record 25 of Set 10 | erenhot
# Processing Record 26 of Set 10 | xichang
# Processing Record 27 of Set 10 | karasjok
# Processing Record 28 of Set 10 | cervo
# Processing Record 29 of Set 10 | isiro
# Processing Record 30 of Set 10 | yeppoon
# Processing Record 31 of Set 10 | yerbogachen
# Processing Record 32 of Set 10 | shatsk
# Processing Record 33 of Set 10 | emmett
# Processing Record 34 of Set 10 | aasiaat
# Processing Record 35 of Set 10 | kamaishi
# Processing Record 36 of Set 10 | nanakuli
# Processing Record 37 of Set 10 | omboue
# Processing Record 38 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 10 | panguma
# Processing Record 40 of Set 10 | tandil
# Processing Record 41 of Set 10 | darhan
# Processing Record 42 of Set 10 | los angeles
# Processing Record 43 of Set 10 | flin flon
# Processing Record 44 of Set 10 | wajima
# Processing Record 45 of Set 10 | santa maria
# Processing Record 46 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | lasa
# Processing Record 48 of Set 10 | bonthe
# Processing Record 49 of Set 10 | jiuquan
# Processing Record 0 of Set 11 | djambala
# Processing Record 1 of Set 11 | praia
# Processing Record 2 of Set 11 | dalbandin
# Processing Record 3 of Set 11 | koslan
# Processing Record 4 of Set 11 | boysun
# Processing Record 5 of Set 11 | mezen
# Processing Record 6 of Set 11 | kinango
# Processing Record 7 of Set 11 | khasan
# Processing Record 8 of Set 11 | berlevag
# Processing Record 9 of Set 11 | banjar
# Processing Record 10 of Set 11 | skibbereen
# Processing Record 11 of Set 11 | rehoboth
# Processing Record 12 of Set 11 | harbour breton
# Processing Record 13 of Set 11 | elk city
# Processing Record 14 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 11 | kosh-agach
# Processing Record 16 of Set 11 | margate
# Processing Record 17 of Set 11 | kodinsk
# Processing Record 18 of Set 11 | natal
# Processing Record 19 of Set 11 | benguela
# Processing Record 20 of Set 11 | dejen
# Processing Record 21 of Set 11 | los barrios
# Processing Record 22 of Set 11 | ardabil
# Processing Record 23 of Set 11 | lavrentiya
# Processing Record 24 of Set 11 | kirovskiy
# Processing Record 25 of Set 11 | clarence town
# Processing Record 26 of Set 11 | mutis
# Processing Record 27 of Set 11 | marevo
# Processing Record 28 of Set 11 | uruzgan
# Processing Record 29 of Set 11 | la rioja
# Processing Record 30 of Set 11 | halifax
# Processing Record 31 of Set 11 | agboville
# Processing Record 32 of Set 11 | umm kaddadah
# Processing Record 33 of Set 11 | curup
# Processing Record 34 of Set 11 | lompoc
# Processing Record 35 of Set 11 | knyaze-volkonskoye
# Processing Record 36 of Set 11 | nizhnedevitsk
# Processing Record 37 of Set 11 | turukhansk
# Processing Record 38 of Set 11 | labuan
# Processing Record 39 of Set 11 | tigil
# Processing Record 40 of Set 11 | uyuni
# Processing Record 41 of Set 11 | qandala
# Processing Record 42 of Set 11 | sisimiut
# Processing Record 43 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 11 | hashtrud
# Processing Record 45 of Set 11 | carmo do rio claro
# Processing Record 46 of Set 11 | kinston
# Processing Record 47 of Set 11 | khudumelapye
# Processing Record 48 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 11 | nishihara
# Processing Record 0 of Set 12 | pitimbu
# Processing Record 1 of Set 12 | bredy
# Processing Record 2 of Set 12 | fort dodge
# Processing Record 3 of Set 12 | abu samrah
# Processing Record 4 of Set 12 | cumra
# Processing Record 5 of Set 12 | bud
# Processing Record 6 of Set 12 | conde
# Processing Record 7 of Set 12 | antalaha
# Processing Record 8 of Set 12 | tankhoy
# Processing Record 9 of Set 12 | anadyr
# Processing Record 10 of Set 12 | livermore
# Processing Record 11 of Set 12 | martapura
# Processing Record 12 of Set 12 | the valley
# Processing Record 13 of Set 12 | saldanha
# Processing Record 14 of Set 12 | goundam
# Processing Record 15 of Set 12 | yola
# Processing Record 16 of Set 12 | palmer
# Processing Record 17 of Set 12 | soyo
# Processing Record 18 of Set 12 | hun
# Processing Record 19 of Set 12 | nantucket
# Processing Record 20 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 12 | kindu
# Processing Record 22 of Set 12 | bandarbeyla
# Processing Record 23 of Set 12 | nanga eboko
# Processing Record 24 of Set 12 | gazanjyk
# Processing Record 25 of Set 12 | tabuk
# Processing Record 26 of Set 12 | grand gaube
# Processing Record 27 of Set 12 | lata
# Processing Record 28 of Set 12 | calasuche
# City not found. Skipping...
# Processing Record 29 of Set 12 | muzhi
# Processing Record 30 of Set 12 | kalbay
# Processing Record 31 of Set 12 | ixtapa
# Processing Record 32 of Set 12 | conceicao do mato dentro
# Processing Record 33 of Set 12 | ende
# Processing Record 34 of Set 12 | huron
# Processing Record 35 of Set 12 | rameshki
# Processing Record 36 of Set 12 | cururupu
# Processing Record 37 of Set 12 | coachella
# Processing Record 38 of Set 12 | okha
# Processing Record 39 of Set 12 | luena
# Processing Record 40 of Set 12 | bima
# Processing Record 41 of Set 12 | hovd
# Processing Record 42 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 12 | mayo
# Processing Record 44 of Set 12 | parana
# Processing Record 45 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 46 of Set 12 | toba
# Processing Record 47 of Set 12 | rorvik
# Processing Record 48 of Set 12 | valparaiso
# Processing Record 49 of Set 12 | san francisco
# Processing Record 0 of Set 13 | half moon bay
# Processing Record 1 of Set 13 | dali
# Processing Record 2 of Set 13 | nizhneudinsk
# Processing Record 3 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 5 of Set 13 | bekhteyevka
# Processing Record 6 of Set 13 | yazman
# Processing Record 7 of Set 13 | zhangjiakou
# Processing Record 8 of Set 13 | noumea
# Processing Record 9 of Set 13 | that phanom
# Processing Record 10 of Set 13 | trenggalek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
type(city_data)
# Out:
# list

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data, columns = ['column_name'])

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
