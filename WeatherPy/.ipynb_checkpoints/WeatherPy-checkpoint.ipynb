# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
cities
# Out:
# Number of cities in the list: 664
# ['kodiak',
#  'severo-kurilsk',
#  'kapaa',
#  'bethel',
#  'roura',
#  'cape town',
#  'fountain hills',
#  'punta arenas',
#  'rikitea',
#  'lushunkou',
#  'ushuaia',
#  'huaicheng',
#  'busselton',
#  'sohag',
#  'tasiilaq',
#  'lolua',
#  'dikson',
#  'awassa',
#  'bredasdorp',
#  'chuy',
#  'ancud',
#  'ribeira grande',
#  'ola',
#  'hilo',
#  'butaritari',
#  'vila velha',
#  'mataura',
#  'torbay',
#  'hermanus',
#  'bluff',
#  'capoterra',
#  'cidreira',
#  'charters towers',
#  'carnarvon',
#  'vostochnyy',
#  'nikolskoye',
#  'sombrio',
#  'amderma',
#  'bantry',
#  'khatanga',
#  'saldanha',
#  'vaini',
#  'sinnamary',
#  'venado tuerto',
#  'georgetown',
#  'altay',
#  'tsihombe',
#  'hobart',
#  'san patricio',
#  'aksu',
#  'hambantota',
#  'rumoi',
#  'matadi',
#  'pevek',
#  'neiafu',
#  'esmeraldas',
#  'hofn',
#  'yellowknife',
#  'tual',
#  'san luis',
#  'hermiston',
#  'clyde river',
#  'pafos',
#  'iquique',
#  'leningradskiy',
#  'atambua',
#  'hojai',
#  'guerrero negro',
#  'cabedelo',
#  'ashqelon',
#  'dunedin',
#  'lavrentiya',
#  'bud',
#  'fortuna',
#  'mar del plata',
#  'alyangula',
#  'airai',
#  'tashla',
#  'lompoc',
#  'conceicao da barra',
#  'verkhnevilyuysk',
#  'vinstra',
#  'awjilah',
#  'ponta do sol',
#  'imbituba',
#  'kirovsk',
#  'neuquen',
#  'nivala',
#  'ilulissat',
#  'atuona',
#  'fare',
#  'sao felix do xingu',
#  'zhezkazgan',
#  'wenling',
#  'grand centre',
#  'minden',
#  'illoqqortoormiut',
#  'avarua',
#  'moree',
#  'olga',
#  'taolanaro',
#  'puerto ayacucho',
#  'boende',
#  'thompson',
#  'port elizabeth',
#  'north myrtle beach',
#  'troitsko-pechorsk',
#  'mutsamudu',
#  'tuktoyaktuk',
#  'phalombe',
#  'pitkyaranta',
#  'saint-joseph',
#  'codrington',
#  'laguna',
#  'poum',
#  'qaanaaq',
#  'moranbah',
#  'longhua',
#  'east london',
#  'amapa',
#  'kandrian',
#  'iquitos',
#  'puerto ayora',
#  'loralai',
#  'yalta',
#  'neka',
#  'formosa',
#  'bin qirdan',
#  'camabatela',
#  'backo gradiste',
#  'arraial do cabo',
#  'belyy yar',
#  'makat',
#  'hithadhoo',
#  'port alfred',
#  'gushikawa',
#  'mana',
#  'esperance',
#  'rio gallegos',
#  'aklavik',
#  'constitucion',
#  'kirando',
#  'taoudenni',
#  'kieta',
#  'palabuhanratu',
#  'lebu',
#  'narsaq',
#  'sobolevo',
#  'victoria',
#  'kalmunai',
#  'nishihara',
#  'nizhneyansk',
#  'menongue',
#  'oyotun',
#  'padang',
#  'srandakan',
#  'hobyo',
#  'mahina',
#  'beringovskiy',
#  'smithers',
#  'brewster',
#  'kaitangata',
#  'shingu',
#  'chokurdakh',
#  'baykit',
#  'sentyabrskiy',
#  'hue',
#  'comodoro rivadavia',
#  'samarai',
#  'castro verde',
#  'sola',
#  'sitka',
#  'north platte',
#  'jumla',
#  'sur',
#  'castro',
#  'bolungarvik',
#  'liverpool',
#  'petropavlovsk-kamchatskiy',
#  'morondava',
#  'kasempa',
#  'jamestown',
#  'boyolangu',
#  'saint george',
#  'norman wells',
#  'burnie',
#  'cayenne',
#  'piacabucu',
#  'altamira',
#  'faanui',
#  'okakarara',
#  'constantine',
#  'kahului',
#  'camacha',
#  'te anau',
#  'aflu',
#  'shumikha',
#  'warrnambool',
#  'new norfolk',
#  'beyneu',
#  'san lazzaro di savena',
#  'qingyuan',
#  'khromtau',
#  'barrow',
#  'kincardine',
#  'ketchikan',
#  'kisangani',
#  'pisco',
#  'xichang',
#  'kavieng',
#  'albany',
#  'chabahar',
#  'tautira',
#  'wilmington',
#  'iqaluit',
#  'nanortalik',
#  'upernavik',
#  'haibowan',
#  'fairlie',
#  'urengoy',
#  'provideniya',
#  'egvekinot',
#  'coxim',
#  'sisimiut',
#  'cap malheureux',
#  'bilibino',
#  'san francisco',
#  'vostok',
#  'bengkulu',
#  'cherskiy',
#  'kropotkin',
#  'borovoy',
#  'pangai',
#  'darhan',
#  'saskylakh',
#  'kodumudi',
#  'mogadishu',
#  'santa marinella',
#  'inirida',
#  'rungata',
#  'labutta',
#  'peniche',
#  'winona',
#  'joao camara',
#  'gizo',
#  'lagoa',
#  'berlevag',
#  'belushya guba',
#  'souillac',
#  'elblag',
#  'ambon',
#  'vaitupu',
#  'kosonsoy',
#  'yuzhno-yeniseyskiy',
#  'mugur-aksy',
#  'russkaya polyana',
#  'baie-comeau',
#  'tougue',
#  'yulara',
#  'uyemskiy',
#  'sao filipe',
#  'cocobeach',
#  'tabiauea',
#  'turukhansk',
#  'luderitz',
#  'nome',
#  'kankaanpaa',
#  'akron',
#  'konstantinovka',
#  'aasiaat',
#  'flinders',
#  'araouane',
#  'makakilo city',
#  'newcastleton',
#  'sapa',
#  'poso',
#  'sabha',
#  'kjollefjord',
#  'zaria',
#  'mayumba',
#  'urucara',
#  'mahebourg',
#  'tarko-sale',
#  'warqla',
#  'tefe',
#  'leh',
#  'mapiri',
#  'karratha',
#  'vao',
#  'carnot',
#  'beira',
#  'gillette',
#  'kavaratti',
#  'kruisfontein',
#  'liberal',
#  'cabo san lucas',
#  'danville',
#  'tekeli',
#  'acapulco',
#  'tiksi',
#  'burns lake',
#  'aleksandrovka',
#  'batemans bay',
#  'paz de ariporo',
#  'meyungs',
#  'urucui',
#  'inuvik',
#  'malanje',
#  'port blair',
#  'dapdap',
#  'mikhaylovskoye',
#  'ostrovnoy',
#  'shahreza',
#  'saint-fabien',
#  'kedougou',
#  'vardo',
#  'kenora',
#  'kaset sombun',
#  'puerto escondido',
#  'miles city',
#  'helmsdale',
#  'buala',
#  'lorengau',
#  'valdivia',
#  'geraldton',
#  'mehamn',
#  'meadow lake',
#  'babanusah',
#  'koungou',
#  'san felipe',
#  'kralendijk',
#  'champerico',
#  'fredericton',
#  'brae',
#  'tilichiki',
#  'edd',
#  'bolshoy tsaryn',
#  'rocha',
#  'kichera',
#  'miraflores',
#  'marawi',
#  'road town',
#  'dhidhdhoo',
#  'benguela',
#  'amga',
#  'yerbogachen',
#  'college',
#  'orahovac',
#  'samusu',
#  'buraydah',
#  'alice springs',
#  'oytal',
#  'rosolini',
#  'itamaraca',
#  'san rafael',
#  'alugan',
#  'muscat',
#  'nuqui',
#  'sao jose da coroa grande',
#  'portland',
#  'north branch',
#  'poltavka',
#  'sangar',
#  'macia',
#  'guerrero',
#  'hervey bay',
#  'hostotipaquillo',
#  'richards bay',
#  'port lincoln',
#  'corsicana',
#  'yichang',
#  'witu',
#  'payo',
#  'sioux lookout',
#  'vestmannaeyjar',
#  'emerald',
#  'jhargram',
#  'tura',
#  'bandarbeyla',
#  'svirstroy',
#  'moultrie',
#  'kpandae',
#  'alta floresta',
#  'namwala',
#  'ashland',
#  'buchanan',
#  'steyr',
#  'iracoubo',
#  'nemuro',
#  'barentsburg',
#  'aykhal',
#  'bouar',
#  'pitimbu',
#  'dengzhou',
#  'muravlenko',
#  'roald',
#  'bonthe',
#  'saleaula',
#  'luanda',
#  'bilma',
#  'kudahuvadhoo',
#  'erzin',
#  'mabamba',
#  'nguiu',
#  'sept-iles',
#  'tessalit',
#  'umzimvubu',
#  'hay river',
#  'mujiayingzi',
#  'kholm',
#  'batagay',
#  'fokino',
#  'pokhara',
#  'syasstroy',
#  'kabare',
#  'chapais',
#  'barra patuca',
#  'ascension',
#  'santiago',
#  'puerto leguizamo',
#  'bogande',
#  'goure',
#  'hasaki',
#  'taguatinga',
#  'hokitika',
#  'sakaiminato',
#  'crestview',
#  'attawapiskat',
#  'koslan',
#  'bonfim',
#  'katsuura',
#  'den helder',
#  'grindavik',
#  'asadabad',
#  'talnakh',
#  'keelung',
#  'trelew',
#  'jalu',
#  'longlac',
#  'dwarka',
#  'san quintin',
#  'zhob',
#  'mount gambier',
#  'katherine',
#  'north bend',
#  'homer',
#  'goderich',
#  'elliot lake',
#  'burica',
#  'miranda de ebro',
#  'pangnirtung',
#  'morro bay',
#  'superior',
#  'olafsvik',
#  'faya',
#  'shimabara',
#  'avera',
#  'acajutla',
#  'isangel',
#  'dingzhou',
#  'lebanon',
#  'fairbanks',
#  'misratah',
#  'sohagpur',
#  'isakly',
#  'tarutyne',
#  'ust-kulom',
#  'stornoway',
#  'blagoveshchenka',
#  'longyearbyen',
#  'uruzgan',
#  'mikhaylovka',
#  'belmonte',
#  'velen',
#  'saint-philippe',
#  'nhamunda',
#  'aripuana',
#  'garden city',
#  'alofi',
#  'sumbe',
#  'lebedinyy',
#  'toora-khem',
#  'bartica',
#  'mecca',
#  'mali',
#  'saint pete beach',
#  'cockburn town',
#  'suicheng',
#  'rafraf',
#  'sawankhalok',
#  'ust-barguzin',
#  'san cristobal',
#  'miramar',
#  'cabra',
#  'dien bien',
#  'hualmay',
#  'opunake',
#  'dezful',
#  'booue',
#  'sal rei',
#  'mount isa',
#  'rodrigues alves',
#  'novokruchininskiy',
#  'virginia beach',
#  'fecamp',
#  'amazar',
#  'rawson',
#  'riyadh',
#  'okhotsk',
#  'touros',
#  'mustasaari',
#  'verkhnetulomskiy',
#  'yar-sale',
#  'sorsk',
#  'lydenburg',
#  'glace bay',
#  'broome',
#  'gornopravdinsk',
#  'parana',
#  'vila',
#  'tres arroyos',
#  'amahai',
#  'marcona',
#  'half moon bay',
#  'toyooka',
#  'maloshuyka',
#  'daru',
#  'vila franca do campo',
#  'bereda',
#  'bandundu',
#  'westport',
#  'severodvinsk',
#  'krivodanovka',
#  'petatlan',
#  'urbano santos',
#  'keetmanshoop',
#  'paamiut',
#  'zemio',
#  'salina',
#  'posse',
#  'rawannawi',
#  'margate',
#  'gamba',
#  'preobrazheniye',
#  'griffith',
#  'haines junction',
#  'faridan',
#  'ucluelet',
#  'dianopolis',
#  'vanavara',
#  'chute-aux-outardes',
#  'talaya',
#  'wagar',
#  'grand gaube',
#  'black river',
#  'ngunguru',
#  'puerto del rosario',
#  'puerto carreno',
#  'lemesos',
#  'shenjiamen',
#  'belaya gora',
#  'tuggurt',
#  'havelock',
#  'fort nelson',
#  'peschanokopskoye',
#  'sinazongwe',
#  'grand river south east',
#  'aiquile',
#  'pangoa',
#  'danesti',
#  'manjacaze',
#  'berdigestyakh',
#  'sperkhias',
#  'samut prakan',
#  'merauke',
#  'gurskoye',
#  'cumaribo',
#  'san andres',
#  'klaksvik',
#  'namibe',
#  'mananara',
#  'orlik',
#  'kleck',
#  'santiago de las vegas',
#  'dicabisagan',
#  'sawtell',
#  'llata',
#  'devonport',
#  'moerai',
#  'port hedland',
#  'takoradi',
#  'wamba',
#  'salalah',
#  'shimoda',
#  'lodwar',
#  'iralaya',
#  'atar',
#  'hastings',
#  'waverly',
#  'beloha',
#  'erenhot',
#  'tecoanapa',
#  'camopi',
#  'kindu',
#  'solwezi',
#  'burley',
#  'broken hill',
#  'moose factory',
#  'karlskrona',
#  'mosquera',
#  'kenai',
#  'utiroa',
#  'rabo de peixe',
#  'yagodnoye',
#  'samalaeulu',
#  'springbok',
#  'san-pedro',
#  'coihaique',
#  'tunduru',
#  'blackfoot',
#  'quatre cocos',
#  'kuliyapitiya',
#  'taltal',
#  'zirc',
#  'grand-lahou',
#  'hihifo',
#  'tuatapere',
#  'bubaque',
#  'monroe',
#  'borgarnes',
#  'lander',
#  'itarema',
#  'kapit',
#  'chifeng',
#  'bhadrachalam',
#  'spornoye',
#  'oranjemund',
#  'inta',
#  'aktas',
#  'saint-francois',
#  'palmer',
#  'buwenge',
#  'navrongo',
#  'kantemirovka',
#  'flin flon',
#  'trairi',
#  'oyama',
#  'tumannyy',
#  'coahuayana',
#  'inhambane',
#  'frontera',
#  'tatawin',
#  'adre',
#  'ahuimanu',
#  'abu samrah',
#  'novokayakent',
#  'rassvet',
#  'vrangel',
#  'balaka',
#  'battipaglia',
#  'horadiz',
#  'khonuu',
#  'coldwater',
#  'anloga']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?" 

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
       
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response_json = requests.get(city_url).json()
        #json.dumps(response_json, indent=4, sort_keys=True)
        #city_weather = response_json["weather"]
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response_json["coord"]["lat"]
        city_lng = response_json["coord"]["lon"]
        city_max_temp = response_json["main"]["temp_max"]
        city_humidity = response_json["main"]["humidity"]
        city_clouds = response_json["clouds"]["all"]
        city_wind = response_json["wind"]["speed"]
        city_country = response_json["sys"]["country"]
        city_date = response_json["dt"]
      

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | roura
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | fountain hills
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | huaicheng
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | sohag
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | awassa
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | ola
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | capoterra
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | charters towers
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | vostochnyy
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | sombrio
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | bantry
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | sinnamary
# Processing Record 44 of Set 1 | venado tuerto
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | altay
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | aksu
# Processing Record 0 of Set 2 | hambantota
# Processing Record 1 of Set 2 | rumoi
# Processing Record 2 of Set 2 | matadi
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | neiafu
# Processing Record 5 of Set 2 | esmeraldas
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | tual
# Processing Record 9 of Set 2 | san luis
# Processing Record 10 of Set 2 | hermiston
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | pafos
# Processing Record 13 of Set 2 | iquique
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | atambua
# Processing Record 16 of Set 2 | hojai
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | cabedelo
# Processing Record 19 of Set 2 | ashqelon
# Processing Record 20 of Set 2 | dunedin
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | bud
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | alyangula
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | tashla
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | conceicao da barra
# Processing Record 30 of Set 2 | verkhnevilyuysk
# Processing Record 31 of Set 2 | vinstra
# Processing Record 32 of Set 2 | awjilah
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | imbituba
# Processing Record 35 of Set 2 | kirovsk
# Processing Record 36 of Set 2 | neuquen
# Processing Record 37 of Set 2 | nivala
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | fare
# Processing Record 41 of Set 2 | sao felix do xingu
# Processing Record 42 of Set 2 | zhezkazgan
# Processing Record 43 of Set 2 | wenling
# Processing Record 44 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 2 | minden
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | avarua
# Processing Record 48 of Set 2 | moree
# Processing Record 49 of Set 2 | olga
# Processing Record 0 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | puerto ayacucho
# Processing Record 2 of Set 3 | boende
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | north myrtle beach
# Processing Record 6 of Set 3 | troitsko-pechorsk
# Processing Record 7 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | phalombe
# Processing Record 10 of Set 3 | pitkyaranta
# Processing Record 11 of Set 3 | saint-joseph
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | laguna
# Processing Record 14 of Set 3 | poum
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | moranbah
# Processing Record 17 of Set 3 | longhua
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | amapa
# Processing Record 20 of Set 3 | kandrian
# Processing Record 21 of Set 3 | iquitos
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | loralai
# Processing Record 24 of Set 3 | yalta
# Processing Record 25 of Set 3 | neka
# Processing Record 26 of Set 3 | formosa
# Processing Record 27 of Set 3 | bin qirdan
# Processing Record 28 of Set 3 | camabatela
# Processing Record 29 of Set 3 | backo gradiste
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | belyy yar
# Processing Record 32 of Set 3 | makat
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | gushikawa
# Processing Record 36 of Set 3 | mana
# Processing Record 37 of Set 3 | esperance
# Processing Record 38 of Set 3 | rio gallegos
# Processing Record 39 of Set 3 | aklavik
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | kirando
# Processing Record 42 of Set 3 | taoudenni
# Processing Record 43 of Set 3 | kieta
# Processing Record 44 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | sobolevo
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | kalmunai
# Processing Record 0 of Set 4 | nishihara
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | menongue
# Processing Record 3 of Set 4 | oyotun
# Processing Record 4 of Set 4 | padang
# Processing Record 5 of Set 4 | srandakan
# Processing Record 6 of Set 4 | hobyo
# Processing Record 7 of Set 4 | mahina
# Processing Record 8 of Set 4 | beringovskiy
# Processing Record 9 of Set 4 | smithers
# Processing Record 10 of Set 4 | brewster
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | shingu
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | baykit
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | hue
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | castro verde
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | north platte
# Processing Record 23 of Set 4 | jumla
# Processing Record 24 of Set 4 | sur
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 4 | liverpool
# Processing Record 28 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 4 | morondava
# Processing Record 30 of Set 4 | kasempa
# Processing Record 31 of Set 4 | jamestown
# Processing Record 32 of Set 4 | boyolangu
# Processing Record 33 of Set 4 | saint george
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | burnie
# Processing Record 36 of Set 4 | cayenne
# Processing Record 37 of Set 4 | piacabucu
# Processing Record 38 of Set 4 | altamira
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | okakarara
# Processing Record 41 of Set 4 | constantine
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | camacha
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 4 | shumikha
# Processing Record 47 of Set 4 | warrnambool
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | beyneu
# Processing Record 0 of Set 5 | san lazzaro di savena
# Processing Record 1 of Set 5 | qingyuan
# Processing Record 2 of Set 5 | khromtau
# Processing Record 3 of Set 5 | barrow
# Processing Record 4 of Set 5 | kincardine
# Processing Record 5 of Set 5 | ketchikan
# Processing Record 6 of Set 5 | kisangani
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | xichang
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | albany
# Processing Record 11 of Set 5 | chabahar
# Processing Record 12 of Set 5 | tautira
# Processing Record 13 of Set 5 | wilmington
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 5 | fairlie
# Processing Record 19 of Set 5 | urengoy
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | egvekinot
# Processing Record 22 of Set 5 | coxim
# Processing Record 23 of Set 5 | sisimiut
# Processing Record 24 of Set 5 | cap malheureux
# Processing Record 25 of Set 5 | bilibino
# Processing Record 26 of Set 5 | san francisco
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | bengkulu
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | kropotkin
# Processing Record 31 of Set 5 | borovoy
# Processing Record 32 of Set 5 | pangai
# Processing Record 33 of Set 5 | darhan
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | kodumudi
# Processing Record 36 of Set 5 | mogadishu
# Processing Record 37 of Set 5 | santa marinella
# Processing Record 38 of Set 5 | inirida
# Processing Record 39 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 5 | peniche
# Processing Record 42 of Set 5 | winona
# Processing Record 43 of Set 5 | joao camara
# Processing Record 44 of Set 5 | gizo
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | elblag
# Processing Record 0 of Set 6 | ambon
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | kosonsoy
# Processing Record 3 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | mugur-aksy
# Processing Record 5 of Set 6 | russkaya polyana
# Processing Record 6 of Set 6 | baie-comeau
# Processing Record 7 of Set 6 | tougue
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | uyemskiy
# Processing Record 10 of Set 6 | sao filipe
# Processing Record 11 of Set 6 | cocobeach
# Processing Record 12 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 6 | turukhansk
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | nome
# Processing Record 16 of Set 6 | kankaanpaa
# Processing Record 17 of Set 6 | akron
# Processing Record 18 of Set 6 | konstantinovka
# Processing Record 19 of Set 6 | aasiaat
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | araouane
# Processing Record 22 of Set 6 | makakilo city
# Processing Record 23 of Set 6 | newcastleton
# Processing Record 24 of Set 6 | sapa
# Processing Record 25 of Set 6 | poso
# Processing Record 26 of Set 6 | sabha
# Processing Record 27 of Set 6 | kjollefjord
# Processing Record 28 of Set 6 | zaria
# Processing Record 29 of Set 6 | mayumba
# Processing Record 30 of Set 6 | urucara
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | tarko-sale
# Processing Record 33 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 6 | tefe
# Processing Record 35 of Set 6 | leh
# Processing Record 36 of Set 6 | mapiri
# Processing Record 37 of Set 6 | karratha
# Processing Record 38 of Set 6 | vao
# Processing Record 39 of Set 6 | carnot
# Processing Record 40 of Set 6 | beira
# Processing Record 41 of Set 6 | gillette
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | liberal
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | danville
# Processing Record 47 of Set 6 | tekeli
# Processing Record 48 of Set 6 | acapulco
# Processing Record 49 of Set 6 | tiksi
# Processing Record 0 of Set 7 | burns lake
# Processing Record 1 of Set 7 | aleksandrovka
# Processing Record 2 of Set 7 | batemans bay
# Processing Record 3 of Set 7 | paz de ariporo
# City not found. Skipping...
# Processing Record 4 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 7 | urucui
# Processing Record 6 of Set 7 | inuvik
# Processing Record 7 of Set 7 | malanje
# Processing Record 8 of Set 7 | port blair
# Processing Record 9 of Set 7 | dapdap
# Processing Record 10 of Set 7 | mikhaylovskoye
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | shahreza
# Processing Record 13 of Set 7 | saint-fabien
# City not found. Skipping...
# Processing Record 14 of Set 7 | kedougou
# Processing Record 15 of Set 7 | vardo
# Processing Record 16 of Set 7 | kenora
# Processing Record 17 of Set 7 | kaset sombun
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | miles city
# Processing Record 20 of Set 7 | helmsdale
# Processing Record 21 of Set 7 | buala
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | valdivia
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | mehamn
# Processing Record 26 of Set 7 | meadow lake
# Processing Record 27 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 7 | koungou
# Processing Record 29 of Set 7 | san felipe
# Processing Record 30 of Set 7 | kralendijk
# Processing Record 31 of Set 7 | champerico
# Processing Record 32 of Set 7 | fredericton
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | tilichiki
# Processing Record 35 of Set 7 | edd
# Processing Record 36 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | kichera
# Processing Record 39 of Set 7 | miraflores
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | road town
# Processing Record 42 of Set 7 | dhidhdhoo
# Processing Record 43 of Set 7 | benguela
# Processing Record 44 of Set 7 | amga
# Processing Record 45 of Set 7 | yerbogachen
# Processing Record 46 of Set 7 | college
# Processing Record 47 of Set 7 | orahovac
# Processing Record 48 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 7 | buraydah
# Processing Record 0 of Set 8 | alice springs
# Processing Record 1 of Set 8 | oytal
# Processing Record 2 of Set 8 | rosolini
# Processing Record 3 of Set 8 | itamaraca
# Processing Record 4 of Set 8 | san rafael
# Processing Record 5 of Set 8 | alugan
# Processing Record 6 of Set 8 | muscat
# Processing Record 7 of Set 8 | nuqui
# Processing Record 8 of Set 8 | sao jose da coroa grande
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | north branch
# Processing Record 11 of Set 8 | poltavka
# Processing Record 12 of Set 8 | sangar
# Processing Record 13 of Set 8 | macia
# Processing Record 14 of Set 8 | guerrero
# Processing Record 15 of Set 8 | hervey bay
# Processing Record 16 of Set 8 | hostotipaquillo
# Processing Record 17 of Set 8 | richards bay
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | corsicana
# Processing Record 20 of Set 8 | yichang
# Processing Record 21 of Set 8 | witu
# Processing Record 22 of Set 8 | payo
# Processing Record 23 of Set 8 | sioux lookout
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | emerald
# Processing Record 26 of Set 8 | jhargram
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | bandarbeyla
# Processing Record 29 of Set 8 | svirstroy
# Processing Record 30 of Set 8 | moultrie
# Processing Record 31 of Set 8 | kpandae
# Processing Record 32 of Set 8 | alta floresta
# Processing Record 33 of Set 8 | namwala
# Processing Record 34 of Set 8 | ashland
# Processing Record 35 of Set 8 | buchanan
# Processing Record 36 of Set 8 | steyr
# Processing Record 37 of Set 8 | iracoubo
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 8 | aykhal
# Processing Record 41 of Set 8 | bouar
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | dengzhou
# Processing Record 44 of Set 8 | muravlenko
# Processing Record 45 of Set 8 | roald
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | bilma
# Processing Record 0 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 9 | erzin
# Processing Record 2 of Set 9 | mabamba
# Processing Record 3 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 9 | sept-iles
# Processing Record 5 of Set 9 | tessalit
# Processing Record 6 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 9 | hay river
# Processing Record 8 of Set 9 | mujiayingzi
# Processing Record 9 of Set 9 | kholm
# Processing Record 10 of Set 9 | batagay
# Processing Record 11 of Set 9 | fokino
# Processing Record 12 of Set 9 | pokhara
# Processing Record 13 of Set 9 | syasstroy
# Processing Record 14 of Set 9 | kabare
# Processing Record 15 of Set 9 | chapais
# Processing Record 16 of Set 9 | barra patuca
# Processing Record 17 of Set 9 | ascension
# Processing Record 18 of Set 9 | santiago
# Processing Record 19 of Set 9 | puerto leguizamo
# Processing Record 20 of Set 9 | bogande
# Processing Record 21 of Set 9 | goure
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | taguatinga
# Processing Record 24 of Set 9 | hokitika
# Processing Record 25 of Set 9 | sakaiminato
# Processing Record 26 of Set 9 | crestview
# Processing Record 27 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 9 | koslan
# Processing Record 29 of Set 9 | bonfim
# Processing Record 30 of Set 9 | katsuura
# Processing Record 31 of Set 9 | den helder
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | asadabad
# Processing Record 34 of Set 9 | talnakh
# Processing Record 35 of Set 9 | keelung
# Processing Record 36 of Set 9 | trelew
# Processing Record 37 of Set 9 | jalu
# Processing Record 38 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 9 | dwarka
# Processing Record 40 of Set 9 | san quintin
# Processing Record 41 of Set 9 | zhob
# Processing Record 42 of Set 9 | mount gambier
# Processing Record 43 of Set 9 | katherine
# Processing Record 44 of Set 9 | north bend
# Processing Record 45 of Set 9 | homer
# Processing Record 46 of Set 9 | goderich
# Processing Record 47 of Set 9 | elliot lake
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | miranda de ebro
# Processing Record 0 of Set 10 | pangnirtung
# Processing Record 1 of Set 10 | morro bay
# Processing Record 2 of Set 10 | superior
# Processing Record 3 of Set 10 | olafsvik
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | shimabara
# Processing Record 6 of Set 10 | avera
# Processing Record 7 of Set 10 | acajutla
# Processing Record 8 of Set 10 | isangel
# Processing Record 9 of Set 10 | dingzhou
# Processing Record 10 of Set 10 | lebanon
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | misratah
# Processing Record 13 of Set 10 | sohagpur
# Processing Record 14 of Set 10 | isakly
# Processing Record 15 of Set 10 | tarutyne
# Processing Record 16 of Set 10 | ust-kulom
# Processing Record 17 of Set 10 | stornoway
# Processing Record 18 of Set 10 | blagoveshchenka
# Processing Record 19 of Set 10 | longyearbyen
# Processing Record 20 of Set 10 | uruzgan
# Processing Record 21 of Set 10 | mikhaylovka
# Processing Record 22 of Set 10 | belmonte
# Processing Record 23 of Set 10 | velen
# Processing Record 24 of Set 10 | saint-philippe
# Processing Record 25 of Set 10 | nhamunda
# Processing Record 26 of Set 10 | aripuana
# Processing Record 27 of Set 10 | garden city
# Processing Record 28 of Set 10 | alofi
# Processing Record 29 of Set 10 | sumbe
# Processing Record 30 of Set 10 | lebedinyy
# Processing Record 31 of Set 10 | toora-khem
# Processing Record 32 of Set 10 | bartica
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | mali
# Processing Record 35 of Set 10 | saint pete beach
# Processing Record 36 of Set 10 | cockburn town
# Processing Record 37 of Set 10 | suicheng
# Processing Record 38 of Set 10 | rafraf
# Processing Record 39 of Set 10 | sawankhalok
# Processing Record 40 of Set 10 | ust-barguzin
# Processing Record 41 of Set 10 | san cristobal
# Processing Record 42 of Set 10 | miramar
# Processing Record 43 of Set 10 | cabra
# Processing Record 44 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 45 of Set 10 | hualmay
# Processing Record 46 of Set 10 | opunake
# Processing Record 47 of Set 10 | dezful
# Processing Record 48 of Set 10 | booue
# Processing Record 49 of Set 10 | sal rei
# Processing Record 0 of Set 11 | mount isa
# Processing Record 1 of Set 11 | rodrigues alves
# Processing Record 2 of Set 11 | novokruchininskiy
# Processing Record 3 of Set 11 | virginia beach
# Processing Record 4 of Set 11 | fecamp
# Processing Record 5 of Set 11 | amazar
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | riyadh
# Processing Record 8 of Set 11 | okhotsk
# Processing Record 9 of Set 11 | touros
# Processing Record 10 of Set 11 | mustasaari
# Processing Record 11 of Set 11 | verkhnetulomskiy
# Processing Record 12 of Set 11 | yar-sale
# Processing Record 13 of Set 11 | sorsk
# Processing Record 14 of Set 11 | lydenburg
# Processing Record 15 of Set 11 | glace bay
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | gornopravdinsk
# Processing Record 18 of Set 11 | parana
# Processing Record 19 of Set 11 | vila
# Processing Record 20 of Set 11 | tres arroyos
# Processing Record 21 of Set 11 | amahai
# Processing Record 22 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 11 | half moon bay
# Processing Record 24 of Set 11 | toyooka
# Processing Record 25 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 11 | daru
# Processing Record 27 of Set 11 | vila franca do campo
# Processing Record 28 of Set 11 | bereda
# Processing Record 29 of Set 11 | bandundu
# Processing Record 30 of Set 11 | westport
# Processing Record 31 of Set 11 | severodvinsk
# Processing Record 32 of Set 11 | krivodanovka
# Processing Record 33 of Set 11 | petatlan
# Processing Record 34 of Set 11 | urbano santos
# Processing Record 35 of Set 11 | keetmanshoop
# Processing Record 36 of Set 11 | paamiut
# Processing Record 37 of Set 11 | zemio
# Processing Record 38 of Set 11 | salina
# Processing Record 39 of Set 11 | posse
# Processing Record 40 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | gamba
# Processing Record 43 of Set 11 | preobrazheniye
# Processing Record 44 of Set 11 | griffith
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 47 of Set 11 | ucluelet
# Processing Record 48 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 49 of Set 11 | vanavara
# Processing Record 0 of Set 12 | chute-aux-outardes
# Processing Record 1 of Set 12 | talaya
# Processing Record 2 of Set 12 | wagar
# Processing Record 3 of Set 12 | grand gaube
# Processing Record 4 of Set 12 | black river
# Processing Record 5 of Set 12 | ngunguru
# Processing Record 6 of Set 12 | puerto del rosario
# Processing Record 7 of Set 12 | puerto carreno
# Processing Record 8 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 9 of Set 12 | shenjiamen
# Processing Record 10 of Set 12 | belaya gora
# Processing Record 11 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 12 | havelock
# Processing Record 13 of Set 12 | fort nelson
# Processing Record 14 of Set 12 | peschanokopskoye
# Processing Record 15 of Set 12 | sinazongwe
# Processing Record 16 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 12 | aiquile
# Processing Record 18 of Set 12 | pangoa
# Processing Record 19 of Set 12 | danesti
# Processing Record 20 of Set 12 | manjacaze
# Processing Record 21 of Set 12 | berdigestyakh
# Processing Record 22 of Set 12 | sperkhias
# City not found. Skipping...
# Processing Record 23 of Set 12 | samut prakan
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 12 | san andres
# Processing Record 28 of Set 12 | klaksvik
# Processing Record 29 of Set 12 | namibe
# Processing Record 30 of Set 12 | mananara
# Processing Record 31 of Set 12 | orlik
# Processing Record 32 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 33 of Set 12 | santiago de las vegas
# Processing Record 34 of Set 12 | dicabisagan
# Processing Record 35 of Set 12 | sawtell
# Processing Record 36 of Set 12 | llata
# Processing Record 37 of Set 12 | devonport
# Processing Record 38 of Set 12 | moerai
# Processing Record 39 of Set 12 | port hedland
# Processing Record 40 of Set 12 | takoradi
# Processing Record 41 of Set 12 | wamba
# Processing Record 42 of Set 12 | salalah
# Processing Record 43 of Set 12 | shimoda
# Processing Record 44 of Set 12 | lodwar
# Processing Record 45 of Set 12 | iralaya
# Processing Record 46 of Set 12 | atar
# Processing Record 47 of Set 12 | hastings
# Processing Record 48 of Set 12 | waverly
# Processing Record 49 of Set 12 | beloha
# Processing Record 0 of Set 13 | erenhot
# Processing Record 1 of Set 13 | tecoanapa
# Processing Record 2 of Set 13 | camopi
# Processing Record 3 of Set 13 | kindu
# Processing Record 4 of Set 13 | solwezi
# Processing Record 5 of Set 13 | burley
# Processing Record 6 of Set 13 | broken hill
# Processing Record 7 of Set 13 | moose factory
# Processing Record 8 of Set 13 | karlskrona
# Processing Record 9 of Set 13 | mosquera
# Processing Record 10 of Set 13 | kenai
# Processing Record 11 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 13 | rabo de peixe
# Processing Record 13 of Set 13 | yagodnoye
# Processing Record 14 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 13 | springbok
# Processing Record 16 of Set 13 | san-pedro
# Processing Record 17 of Set 13 | coihaique
# Processing Record 18 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 13 | blackfoot
# Processing Record 20 of Set 13 | quatre cocos
# Processing Record 21 of Set 13 | kuliyapitiya
# Processing Record 22 of Set 13 | taltal
# Processing Record 23 of Set 13 | zirc
# Processing Record 24 of Set 13 | grand-lahou
# Processing Record 25 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 13 | tuatapere
# Processing Record 27 of Set 13 | bubaque
# Processing Record 28 of Set 13 | monroe
# Processing Record 29 of Set 13 | borgarnes
# Processing Record 30 of Set 13 | lander
# Processing Record 31 of Set 13 | itarema
# Processing Record 32 of Set 13 | kapit
# Processing Record 33 of Set 13 | chifeng
# Processing Record 34 of Set 13 | bhadrachalam
# Processing Record 35 of Set 13 | spornoye
# Processing Record 36 of Set 13 | oranjemund
# Processing Record 37 of Set 13 | inta
# Processing Record 38 of Set 13 | aktas
# Processing Record 39 of Set 13 | saint-francois
# Processing Record 40 of Set 13 | palmer
# Processing Record 41 of Set 13 | buwenge
# Processing Record 42 of Set 13 | navrongo
# Processing Record 43 of Set 13 | kantemirovka
# Processing Record 44 of Set 13 | flin flon
# Processing Record 45 of Set 13 | trairi
# Processing Record 46 of Set 13 | oyama
# Processing Record 47 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 13 | coahuayana
# Processing Record 49 of Set 13 | inhambane
# Processing Record 0 of Set 14 | frontera
# Processing Record 1 of Set 14 | tatawin
# Processing Record 2 of Set 14 | adre
# Processing Record 3 of Set 14 | ahuimanu
# Processing Record 4 of Set 14 | abu samrah
# Processing Record 5 of Set 14 | novokayakent
# Processing Record 6 of Set 14 | rassvet
# Processing Record 7 of Set 14 | vrangel
# Processing Record 8 of Set 14 | balaka
# Processing Record 9 of Set 14 | battipaglia
# Processing Record 10 of Set 14 | horadiz
# Processing Record 11 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 14 | coldwater
# Processing Record 13 of Set 14 | anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 611

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          611
# Lat           611
# Lng           611
# Max Temp      611
# Humidity      611
# Cloudiness    611
# Wind Speed    611
# Country       611
# Date          611
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kodiak  57.7900 -152.4072      2.73        93         100
# 1  severo-kurilsk  50.6789  156.1250     -3.59        52          63
# 2           kapaa  22.0752 -159.3190     25.99        83          20
# 3          bethel  41.3712  -73.4140     -1.25        60          75
# 4           roura   4.7263  -52.3274     22.95       100           0
#
#    Wind Speed Country        Date
# 0        2.57      US  1675222061
# 1        1.55      RU  1675222061
# 2        4.12      US  1675222062
# 3        2.06      US  1675221981
# 4        0.51      GF  1675222062

# %%
# Export the City_Data into a csv

city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kodiak  57.7900 -152.4072      2.73        93         100
# 1        severo-kurilsk  50.6789  156.1250     -3.59        52          63
# 2                 kapaa  22.0752 -159.3190     25.99        83          20
# 3                bethel  41.3712  -73.4140     -1.25        60          75
# 4                 roura   4.7263  -52.3274     22.95       100           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1675222061
# 1              1.55      RU  1675222061
# 2              4.12      US  1675222062
# 3              2.06      US  1675221981
# 4              0.51      GF  1675222062

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(x="Lat",y="Max Temp",kind="scatter",marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.suptitle('City Latitude vs Maximum Temperature')
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(x="Lat",y="Humidity",kind="scatter",marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.suptitle('City Latitude vs Humidity')
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(x="Lat",y="Cloudiness",kind="scatter",marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.suptitle('City Latitude vs Cloudiness')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(x="Lat",y="Wind Speed",kind="scatter",marker="o")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.suptitle('City Latitude vs Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy import stats

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kodiak  57.7900 -152.4072      2.73        93         100
# 1        severo-kurilsk  50.6789  156.1250     -3.59        52          63
# 2                 kapaa  22.0752 -159.3190     25.99        83          20
# 3                bethel  41.3712  -73.4140     -1.25        60          75
# 4                 roura   4.7263  -52.3274     22.95       100           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1675222061
# 1              1.55      RU  1675222061
# 2              4.12      US  1675222062
# 3              2.06      US  1675221981
# 4              0.51      GF  1675222062

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5           cape town -33.9258   18.4232     22.43        81          20
# 7        punta arenas -53.1500  -70.9167     12.06        62          75
# 8             rikitea -23.1203 -134.9692     26.23        69           4
# 9             ushuaia -54.8000  -68.3000     13.81        51          40
# 11          busselton -33.6500  115.3333     24.40        38           0
#
#          Wind Speed Country        Date
# City_ID
# 5              5.66      ZA  1675221913
# 7              7.72      CL  1675222063
# 8              6.32      PF  1675221799
# 9              6.17      AR  1675222064
# 11             5.75      AU  1675222064

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope,intercept,rvalue,pvalue,strderr) = stats.linregress(x_values,y_values)
predicted_values = x_values * slope + intercept

plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")

line_eq = f"y={round(slope,2)}x+{round(intercept,2)}"
plt.annotate(line_eq,xy=(30,-30),fontsize=15,color="red")

plt.plot(x_values,predicted_values,"r-")
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7203458598089965

# %%
# Linear regression on Southern Hemisphere
x_values1 = southern_hemi_df['Lat']
y_values1 = southern_hemi_df['Max Temp']

(slope1,intercept1,rvalue1,pvalue1,strderr1) = stats.linregress(x_values1,y_values1)
predicted_values1 = x_values1 * slope1 + intercept1

plt.scatter(x_values1,y_values1)
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")

line_eq1 = f"y={round(slope1,2)}x+{round(intercept1,2)}"
plt.annotate(line_eq1,xy=(-30,17),fontsize=15,color="red")

plt.plot(x_values1,predicted_values1,"r-")
print(f"The r-value is: {rvalue1**2}")
# Out:
# The r-value is: 0.17094342307472607

# %% [markdown]
# **Discussion about the linear relationship:** The r-value for the southern hemispher indicates a weak uphill (positive) linear relationship between latitude and maximum temperature.  For the northern hemisphere, the r-value indicates a strong uphill (positive) linear relationship between latitude and maximum temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values2 = northern_hemi_df['Humidity']

(slope2,intercept2,rvalue2,pvalue2,strderr2) = stats.linregress(x_values,y_values2)
predicted_values2 = x_values * slope2 + intercept2

plt.scatter(x_values,y_values2)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

line_eq2 = f"y={round(slope2,2)}x+{round(intercept2,2)}"
plt.annotate(line_eq2,xy=(50,60),fontsize=15,color="red")

plt.plot(x_values,predicted_values2,"r-")
print(f"The r-value is: {rvalue2**2}")
# Out:
# The r-value is: 0.1545459460813381

# %%
# Southern Hemisphere
#x_values1 = southern_hemi_df['Lat']
y_values3 = southern_hemi_df['Humidity']

(slope3,intercept3,rvalue3,pvalue3,strderr3) = stats.linregress(x_values1,y_values3)
predicted_values3 = x_values1 * slope3 + intercept3

plt.scatter(x_values1,y_values3)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

line_eq3 = f"y={round(slope3,2)}x+{round(intercept3,2)}"
plt.annotate(line_eq3,xy=(-30,55),fontsize=15,color="red")

plt.plot(x_values1,predicted_values3,"r-")
print(f"The r-value is: {rvalue3**2}")
# Out:
# The r-value is: 0.1682626951865688

# %% [markdown]
# **Discussion about the linear relationship:** The r-value for both hemispher indicates a very weak uphill (positive) linear relationship between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
#x_values = northern_hemi_df['Lat']
y_values4 = northern_hemi_df['Cloudiness']

(slope4,intercept4,rvalue4,pvalue4,strderr4) = stats.linregress(x_values,y_values4)
predicted_values4 = x_values * slope4 + intercept4

plt.scatter(x_values,y_values4)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

line_eq4 = f"y={round(slope4,2)}x+{round(intercept4,2)}"
plt.annotate(line_eq4,xy=(35,45),fontsize=15,color="red")

plt.plot(x_values,predicted_values4,"r-")
print(f"The r-value is: {rvalue4**2}")
# Out:
# The r-value is: 0.11472947930411256

# %%
# Southern Hemisphere
#x_values1 = southern_hemi_df['Lat']
y_values5 = southern_hemi_df['Cloudiness']

(slope5,intercept5,rvalue5,pvalue5,strderr5) = stats.linregress(x_values1,y_values5)
predicted_values5 = x_values1 * slope5 + intercept5

plt.scatter(x_values1,y_values5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

line_eq5 = f"y={round(slope5,2)}x+{round(intercept5,2)}"
plt.annotate(line_eq5,xy=(-30,40),fontsize=15,color="red")

plt.plot(x_values1,predicted_values5,"r-")
print(f"The r-value is: {rvalue5**2}")
# Out:
# The r-value is: 0.13044758596211473

# %% [markdown]
# **Discussion about the linear relationship:** The r-value for both hemispher indicates a very weak uphill (positive) linear relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
#x_values = northern_hemi_df['Lat']
y_values6 = northern_hemi_df['Wind Speed']

(slope6,intercept6,rvalue6,pvalue6,strderr6) = stats.linregress(x_values,y_values6)
predicted_values6 = x_values * slope6 + intercept6

plt.scatter(x_values,y_values6)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

line_eq6 = f"y={round(slope6,2)}x+{round(intercept6,2)}"
plt.annotate(line_eq6,xy=(35,7),fontsize=15,color="red")

plt.plot(x_values,predicted_values6,"r-")
print(f"The r-value is: {rvalue6**2}")
# Out:
# The r-value is: 0.021764645030966374

# %%
# Southern Hemisphere
#x_values1 = southern_hemi_df['Lat']
y_values7 = southern_hemi_df['Wind Speed']

(slope7,intercept7,rvalue7,pvalue7,strderr7) = stats.linregress(x_values1,y_values7)
predicted_values7 = x_values1 * slope7 + intercept7

plt.scatter(x_values1,y_values7)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

line_eq7 = f"y={round(slope7,2)}x+{round(intercept7,2)}"
plt.annotate(line_eq7,xy=(-50,6),fontsize=17,color="red")

plt.plot(x_values1,predicted_values7,"r-")
print(f"The r-value is: {rvalue7**2}")
# Out:
# The r-value is: 0.09190123315498538

# %% [markdown]
# **Discussion about the linear relationship:** The r-value for both hemispher indicates a very weak  linear relationship between latitude and windspeed.
